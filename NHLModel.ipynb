# %%
import sklearn

# %%
import pandas as pd
df = pd.read_csv('NHLSchedule.csv')
df.head()
# Out:
#          Date              Visitor  VG                  Home  HG OT/SO Notes  \
# 0  10/10/2023   Chicago Blackhawks   4   Pittsburgh Penguins   2   NaN   NaN
# 1  10/10/2023  Nashville Predators   3   Tampa Bay Lightning   5   NaN   NaN
# 2  10/10/2023       Seattle Kraken   1  Vegas Golden Knights   4   NaN   NaN
# 3  10/11/2023   Chicago Blackhawks   1         Boston Bruins   3   NaN   NaN
# 4  10/11/2023      Ottawa Senators   3   Carolina Hurricanes   5   NaN   NaN
#
#    Result  Gtotal
# 0      -2       6
# 1       2       8
# 2       3       5
# 3       2       4
# 4       2       8

# %%
df1 = pd.read_csv('HomeTeamStats.csv')
df1.head()
# Out:
#                     HTm  HRk  HAvAge  HGF/G  HGA/G  HPP  HPPO   HPP%  HPPA  \
# 0  Vegas Golden Knights    1    28.5   3.64   2.18   10    39  25.64     4
# 1         Boston Bruins    2    28.4   3.10   1.60    5    32  15.63     1
# 2      New York Rangers    3    28.4   3.00   1.90   12    37  32.43     6
# 3     Vancouver Canucks    4    28.3   4.60   2.20   12    35  34.29     9
# 4          Dallas Stars    5    28.9   3.22   2.56    3    25  12.00     2
#
#    HPPOA   HPK%  HSH  HSHA  HPIM/G  HoPIM/G   HS   HS%  HSA   HSV%  HSO
# 0     34  88.24    0     1    10.2     10.0  314  12.7  329  0.927    0
# 1     39  97.44    0     0    11.1      9.4  320   9.7  299  0.946    1
# 2     33  81.82    1     1    10.5     13.3  280  10.7  263  0.928    1
# 3     38  76.32    2     0    11.1     10.5  285  16.1  305  0.928    1
# 4     31  93.55    1     3     9.0      8.8  265  10.9  310  0.926    0

# %%
df2 = pd.merge(df, df1, left_on=['Home'], right_on=['HTm'], how="left")
df2.head()
# Out:
#          Date              Visitor  VG                  Home  HG OT/SO Notes  \
# 0  10/10/2023   Chicago Blackhawks   4   Pittsburgh Penguins   2   NaN   NaN
# 1  10/10/2023  Nashville Predators   3   Tampa Bay Lightning   5   NaN   NaN
# 2  10/10/2023       Seattle Kraken   1  Vegas Golden Knights   4   NaN   NaN
# 3  10/11/2023   Chicago Blackhawks   1         Boston Bruins   3   NaN   NaN
# 4  10/11/2023      Ottawa Senators   3   Carolina Hurricanes   5   NaN   NaN
#
#    Result  Gtotal                   HTm  ...   HPK%  HSH  HSHA  HPIM/G  \
# 0      -2       6   Pittsburgh Penguins  ...  82.14    0     1     8.2
# 1       2       8   Tampa Bay Lightning  ...  88.46    0     0     8.1
# 2       3       5  Vegas Golden Knights  ...  88.24    0     1    10.2
# 3       2       4         Boston Bruins  ...  97.44    0     0    11.1
# 4       2       8   Carolina Hurricanes  ...  75.56    4     3    14.2
#
#    HoPIM/G   HS   HS%  HSA   HSV%  HSO
# 0      7.8  323   8.0  259  0.888    2
# 1     11.3  295  11.5  349  0.908    2
# 2     10.0  314  12.7  329  0.927    0
# 3      9.4  320   9.7  299  0.946    1
# 4     10.9  378   9.8  287  0.864    1
#
# [5 rows x 29 columns]

# %%
df3 = pd.read_csv('VisitorTeamStats.csv')
df3.head()
# Out:
#                     VTm  VRk  VAvAge  VGF/G  VGA/G  VPP  VPPO   VPP%  VPPA  \
# 0  Vegas Golden Knights    1    28.5   3.64   2.18   10    39  25.64     4
# 1         Boston Bruins    2    28.4   3.10   1.60    5    32  15.63     1
# 2      New York Rangers    3    28.4   3.00   1.90   12    37  32.43     6
# 3     Vancouver Canucks    4    28.3   4.60   2.20   12    35  34.29     9
# 4          Dallas Stars    5    28.9   3.22   2.56    3    25  12.00     2
#
#    VPPOA   VPK%  VSH  VSHA  VPIM/G  VoPIM/G   VS   VS%  VSA   VSV%  VSO
# 0     34  88.24    0     1    10.2     10.0  314  12.7  329  0.927    0
# 1     39  97.44    0     0    11.1      9.4  320   9.7  299  0.946    1
# 2     33  81.82    1     1    10.5     13.3  280  10.7  263  0.928    1
# 3     38  76.32    2     0    11.1     10.5  285  16.1  305  0.928    1
# 4     31  93.55    1     3     9.0      8.8  265  10.9  310  0.926    0

# %%
df4 =  pd.merge(df2, df3, left_on=['Visitor'], right_on=['VTm'], how="left")
df4.head()
# Out:
#          Date              Visitor  VG                  Home  HG OT/SO Notes  \
# 0  10/10/2023   Chicago Blackhawks   4   Pittsburgh Penguins   2   NaN   NaN
# 1  10/10/2023  Nashville Predators   3   Tampa Bay Lightning   5   NaN   NaN
# 2  10/10/2023       Seattle Kraken   1  Vegas Golden Knights   4   NaN   NaN
# 3  10/11/2023   Chicago Blackhawks   1         Boston Bruins   3   NaN   NaN
# 4  10/11/2023      Ottawa Senators   3   Carolina Hurricanes   5   NaN   NaN
#
#    Result  Gtotal                   HTm  ...   VPK%  VSH  VSHA  VPIM/G  \
# 0      -2       6   Pittsburgh Penguins  ...  86.67    1     2    11.1
# 1       2       8   Tampa Bay Lightning  ...  69.70    1     0     8.0
# 2       3       5  Vegas Golden Knights  ...  74.19    1     2     8.8
# 3       2       4         Boston Bruins  ...  86.67    1     2    11.1
# 4       2       8   Carolina Hurricanes  ...  75.76    1     2    14.3
#
#    VoPIM/G   VS   VS%  VSA   VSV%  VSO
# 0     10.9  237   8.0  308  0.896    0
# 1      9.8  312   8.7  290  0.897    1
# 2      9.5  350   8.0  360  0.903    0
# 3     10.9  237   8.0  308  0.896    0
# 4     15.9  302  11.3  276  0.895    0
#
# [5 rows x 49 columns]

# %%
df4.to_csv('TrainData.csv')

# %%
df5 = pd.read_csv('TrainData.csv')

# %%
df_output = df5[['Result','Gtotal']]
df_output.head()
# Out:
#    Result  Gtotal
# 0      -2       6
# 1       2       8
# 2       3       5
# 3       2       4
# 4       2       8

# %%
df_stats =  df5[['HRk','HAvAge','HGF/G','HGA/G','HPP','HPPO','HPP%','HPPA','HPPOA','HPK%','HSH','HSHA',
             'HPIM/G','HoPIM/G','HS','HS%','HSA','HSV%','HSO',
             'VRk','VAvAge','VGF/G','VGA/G','VPP','VPPO','VPP%','VPPA','VPPOA','VPK%','VSH','VSHA',
             'VPIM/G','VoPIM/G','VS','VS%','VSA','VSV%','VSO']]
df_stats.head()
# Out:
#    HRk  HAvAge  HGF/G  HGA/G  HPP  HPPO   HPP%  HPPA  HPPOA   HPK%  ...  \
# 0   28    31.4   2.89   3.22    4    27  14.81     5     28  82.14  ...
# 1   16    28.5   3.40   3.20   10    33  30.30     3     26  88.46  ...
# 2    1    28.5   3.64   2.18   10    39  25.64     4     34  88.24  ...
# 3    2    28.4   3.10   1.60    5    32  15.63     1     39  97.44  ...
# 4   11    29.6   3.36   3.55   11    42  26.19    11     45  75.56  ...
#
#     VPK%  VSH  VSHA  VPIM/G  VoPIM/G   VS   VS%  VSA   VSV%  VSO
# 0  86.67    1     2    11.1     10.9  237   8.0  308  0.896    0
# 1  69.70    1     0     8.0      9.8  312   8.7  290  0.897    1
# 2  74.19    1     2     8.8      9.5  350   8.0  360  0.903    0
# 3  86.67    1     2    11.1     10.9  237   8.0  308  0.896    0
# 4  75.76    1     2    14.3     15.9  302  11.3  276  0.895    0
#
# [5 rows x 38 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
predictor = LinearRegression(n_jobs=-1)

predictor.fit(X=df_stats, y=df_output)
# Out:
# LinearRegression(n_jobs=-1)

# %%
df6 = pd.read_csv('TestData.csv')
df6.head()
# Out:
#         Date              Visitor  VG                Home  HG  OT/SO  Notes  \
# 0  11/3/2023  Philadelphia Flyers NaN      Buffalo Sabres NaN    NaN    NaN
# 1  11/3/2023    New Jersey Devils NaN     St. Louis Blues NaN    NaN    NaN
# 2  11/4/2023        Winnipeg Jets NaN     Arizona Coyotes NaN    NaN    NaN
# 3  11/4/2023     Florida Panthers NaN  Chicago Blackhawks NaN    NaN    NaN
# 4  11/4/2023        Boston Bruins NaN   Detroit Red Wings NaN    NaN    NaN
#
#    Result  Gtotal
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN

# %%
df7 = pd.merge(df6, df1, left_on=['Home'], right_on=['HTm'], how="left")
df7.head()
# Out:
#         Date              Visitor  VG                Home  HG  OT/SO  Notes  \
# 0  11/3/2023  Philadelphia Flyers NaN      Buffalo Sabres NaN    NaN    NaN
# 1  11/3/2023    New Jersey Devils NaN     St. Louis Blues NaN    NaN    NaN
# 2  11/4/2023        Winnipeg Jets NaN     Arizona Coyotes NaN    NaN    NaN
# 3  11/4/2023     Florida Panthers NaN  Chicago Blackhawks NaN    NaN    NaN
# 4  11/4/2023        Boston Bruins NaN   Detroit Red Wings NaN    NaN    NaN
#
#    Result  Gtotal                 HTm  ...   HPK%  HSH  HSHA  HPIM/G  HoPIM/G  \
# 0     NaN     NaN      Buffalo Sabres  ...  90.00    1     2    13.3     12.4
# 1     NaN     NaN     St. Louis Blues  ...  78.26    1     1     7.6      9.4
# 2     NaN     NaN     Arizona Coyotes  ...  72.22    0     0    17.2     14.4
# 3     NaN     NaN  Chicago Blackhawks  ...  86.67    1     2    11.1     10.9
# 4     NaN     NaN   Detroit Red Wings  ...  83.33    0     1    10.3     11.2
#
#     HS   HS%  HSA   HSV%  HSO
# 0  285  11.2  313  0.907    1
# 1  201   7.0  260  0.912    1
# 2  297  11.1  315  0.914    0
# 3  237   8.0  308  0.896    0
# 4  331  12.1  341  0.903    1
#
# [5 rows x 29 columns]

# %%
df8 = pd.merge(df7, df3, left_on=['Visitor'], right_on=['VTm'], how="left")
df8.head()
# Out:
#         Date              Visitor  VG                Home  HG  OT/SO  Notes  \
# 0  11/3/2023  Philadelphia Flyers NaN      Buffalo Sabres NaN    NaN    NaN
# 1  11/3/2023    New Jersey Devils NaN     St. Louis Blues NaN    NaN    NaN
# 2  11/4/2023        Winnipeg Jets NaN     Arizona Coyotes NaN    NaN    NaN
# 3  11/4/2023     Florida Panthers NaN  Chicago Blackhawks NaN    NaN    NaN
# 4  11/4/2023        Boston Bruins NaN   Detroit Red Wings NaN    NaN    NaN
#
#    Result  Gtotal                 HTm  ...   VPK%  VSH  VSHA  VPIM/G  VoPIM/G  \
# 0     NaN     NaN      Buffalo Sabres  ...  77.78    4     1    10.6     11.2
# 1     NaN     NaN     St. Louis Blues  ...  73.53    1     0    10.1     11.1
# 2     NaN     NaN     Arizona Coyotes  ...  69.44    2     1    11.2     10.6
# 3     NaN     NaN  Chicago Blackhawks  ...  72.73    1     1     8.8     10.2
# 4     NaN     NaN   Detroit Red Wings  ...  97.44    0     0    11.1      9.4
#
#     VS   VS%  VSA   VSV%  VSO
# 0  334   9.6  268  0.877    1
# 1  299  12.7  270  0.881    0
# 2  329   9.4  288  0.878    0
# 3  302   7.9  258  0.911    1
# 4  320   9.7  299  0.946    1
#
# [5 rows x 49 columns]

# %%
df_test = df8[['HRk','HAvAge','HGF/G','HGA/G','HPP','HPPO','HPP%','HPPA','HPPOA','HPK%','HSH','HSHA',
             'HPIM/G','HoPIM/G','HS','HS%','HSA','HSV%','HSO',
             'VRk','VAvAge','VGF/G','VGA/G','VPP','VPPO','VPP%','VPPA','VPPOA','VPK%','VSH','VSHA',
             'VPIM/G','VoPIM/G','VS','VS%','VSA','VSV%','VSO']]
df_test.head()
# Out:
#    HRk  HAvAge  HGF/G  HGA/G  HPP  HPPO   HPP%  HPPA  HPPOA   HPK%  ...  \
# 0   20    25.8   3.20   2.90    3    30  10.00     4     40  90.00  ...
# 1   27    28.9   1.75   2.88    1    25   4.00     5     23  78.26  ...
# 2   15    26.5   3.30   2.70   10    42  23.81    10     36  72.22  ...
# 3   29    27.4   2.11   3.56    3    33   9.09     4     30  86.67  ...
# 4    8    28.5   3.64   3.00   12    42  28.57     7     42  83.33  ...
#
#     VPK%  VSH  VSHA  VPIM/G  VoPIM/G   VS   VS%  VSA   VSV%  VSO
# 0  77.78    4     1    10.6     11.2  334   9.6  268  0.877    1
# 1  73.53    1     0    10.1     11.1  299  12.7  270  0.881    0
# 2  69.44    2     1    11.2     10.6  329   9.4  288  0.878    0
# 3  72.73    1     1     8.8     10.2  302   7.9  258  0.911    1
# 4  97.44    0     0    11.1      9.4  320   9.7  299  0.946    1
#
# [5 rows x 38 columns]

# %%
outcome = predictor.predict(X=df_test)


print(outcome)
# Out:
# [[ 0.0404867   6.13429461]
#  [-4.42280251  5.60316259]
#  [ 2.45184353  5.87576302]
#  [-1.04959128  4.16413158]
#  [-2.03001919  4.3958268 ]
#  [ 0.01344753  6.05319566]
#  [-1.23517582  7.2918371 ]
#  [ 1.54734552  7.22078098]
#  [ 2.81197538  8.03471323]
#  [-2.47889601  5.84823024]
#  [ 2.24099558  7.60642249]
#  [-0.72335391  7.19289079]
#  [-2.77830983  4.4277982 ]
#  [-1.3484705   6.79495895]
#  [ 2.24075166  6.96989826]
#  [ 1.20214651  5.07657056]
#  [-1.8597731   5.81488035]
#  [-1.21445426  5.72996729]
#  [-2.00117297  6.6345207 ]]
